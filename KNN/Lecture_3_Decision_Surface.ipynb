# %% [markdown]
# # 1. Decision Boundary for Knn
# ### 1. What is Decision Boundary
# >In a classification problem with two or more classes, a decision boundary or decision surface is a hypersurface that partitions the underlying vector space into two or more sets, one for each class. The classifier will classify all the points on one side of the decision boundary as belonging to one class and all those on the other side as belonging to the other class.

# %% [markdown]
# ![Screenshot 2026-01-12 104508.png](attachment:0f49f33e-6248-499a-a100-b68aafc7531a.png)

# %% [markdown]
# # Important Points
# 1. We can draw decision boundary for all the classification algorithms including Neural networks
# 2. Decision boundary can be both linear(as in the case of SVM) or non-linear(as in the case of Decision tree classifier or Knn)
# 3. Decision boundaries are not always clear cut. That is, the transition from one class in the feature space to another is not discontinuous, but gradual. This effect is common in fuzzy logic based classification algorithms, where membership in one class or another is ambiguous.
# 4. For higher dimension problems the decision boundary acts as a hyperplane (for linear ones)

# %% [markdown]
# ![Screenshot 2026-01-12 104929.png](attachment:57550c83-56c5-4af4-9456-c0dfab7583bd.png)

# %% [markdown]
# # 3. Steps to plot Decision Boundary for Knn(Assuming 2 input cols)
# 1. Train the classifier on the training set.
# 2. Create a uniform grid(with the help of Numpy Meshgrids) of points that densely cover the region of input space containing the training set.
# 3. Classify each point on the grid. Store the results in an array A, where Aij contains the predicted class for the point at row 1, column j on the grid.
# 4. Plot the array as an image, where each pixel corresponds to a grid point and its color represents the predicted class. The decision boundary can be seen as contours where the image changes color.
# 5. Finally print out the training data with their respective color on the same contour

# %% [markdown]
# ## Step 2: Creating a Meshgrid

# %% [markdown]
# ![Screenshot 2026-01-12 110038.png](attachment:5ba09852-5cbd-452e-81cf-332668ae20cb.png)
# ![Screenshot 2026-01-12 110149.png](attachment:3e7961bf-1d2f-4cda-b1b7-d34dc33d2b9e.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3])
y = np.array([4,5,6,7])
xx, yy = np.meshgrid(x,y)

# %%
xx.shape
# Out:
# (4, 3)

# %%
yy.shape
# Out:
# (4, 3)

# %% [markdown]
# ## Purpose of Meshgrid
# Meshgrid is very useful to evaluate functions on a grid . we can apply any functions to the points of a meahgrid to plot a function

# %% [markdown]
# ## Plotting a function using Meshgrid

# %%
x = np.linspace(-40,40,100)
y = np.linspace(-50,50,100)
xx, yy = np.meshgrid(x,y)

# %%
xx.shape
# Out:
# (100, 100)

# %%
yy.shape
# Out:
# (100, 100)

# %%
z = xx**2 + yy**2

# %%
plt.contour(xx,yy,z)

# %%
x = np.linspace(-20,20,25)
y = np.linspace(-20,20,25)
xx, yy = np.meshgrid(x,y)
print(xx.shape,yy.shape)
# Out:
# (25, 25) (25, 25)

# %%
z = np.random.random((25,25))
plt.contour(xx,yy,z)

# %%
x = np.linspace(-40,40,50)
y = np.linspace(-50,50,50)
xx, yy = np.meshgrid(x,y)
print(xx.shape,yy.shape)
# Out:
# (50, 50) (50, 50)

# %%
z = np.random.random((50,50))
plt.contour(xx,yy,z)

# %%
x = np.linspace(-40,40,100)
y = np.linspace(-50,50,100)
xx, yy = np.meshgrid(x,y)

# %%
z = np.random.random((100,100))

# %%
plt.contour(xx,yy,z)

# %%
x = np.linspace(-40,40,1000)
y = np.linspace(-50,50,900)
xx, yy = np.meshgrid(x,y)
print(xx.shape,yy.shape)
# Out:
# (900, 1000) (900, 1000)

# %%
z = np.random.random((900,1000))
plt.contour(xx,yy,z)

# %% [markdown]
# ## Step 2: Creating a Meshgrid

# %%
a = np.arange(start=-10,stop=10,step=1)
b = np.arange(start=-10,stop=10,step=1)
xx,yy=np.meshgrid(a,b)
plt.scatter(xx,yy,c='g')

# %%
a = np.arange(start=-20,stop=20,step=1)
b = np.arange(start=-20,stop=20,step=1)
xx,yy=np.meshgrid(a,b)
plt.scatter(xx,yy,c='g')

# %%
a = np.arange(start=-25,stop=25,step=1)
b = np.arange(start=-25,stop=25,step=1)
xx,yy=np.meshgrid(a,b)
plt.scatter(xx,yy,c='g')

# %%
a = np.arange(start=-30,stop=30,step=1)
b = np.arange(start=-30,stop=30,step=1)
xx,yy=np.meshgrid(a,b)
plt.scatter(xx,yy,c='g')

# %%
a = np.arange(start=-40,stop=40,step=1)
b = np.arange(start=-40,stop=40,step=1)
xx,yy=np.meshgrid(a,b)
plt.scatter(xx,yy,c='g')
